# %%
import time
import requests
import json
import pandas as pd
import config
import matplotlib.pyplot as plt
import datetime
from csv import writer

# %%
#Combine csv data frame file if in DF Creation there where issues with running program all at once  

# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\co_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\co_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no2_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no2_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\o3_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\o3_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\so2_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\so2_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm2_5_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm2_5_data.csv', encoding='latin-1')
# left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm10_data_2.csv', encoding='latin-1')
# right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm10_data.csv', encoding='latin-1')
left=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\nh3_data_2.csv', encoding='latin-1')
right=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\nh3_data.csv', encoding='latin-1')

frames=[left, right]
new=pd.concat(frames)
new
# Out:
#                 city      lat       lon  nh3_2020_11_27  nh3_2020_11_28  \
# 0            Wrigley  35.8997  -87.3537         0.00375         0.27000
# 1              Cowan  37.5601 -120.9888         0.16083        11.61042
# 2      Strattanville  41.2025  -79.3268         0.00542         0.21250
# 3         SmithRiver  41.9249 -124.1494         0.00833         0.32667
# 4           Laddonia  39.2434  -91.6424         0.01792         0.66458
# ...              ...      ...       ...             ...             ...
# 18559     Litchfield  40.3877 -120.3809         0.05208         1.65792
# 18560          Bruce  44.4378  -96.8906         0.06417         1.57958
# 18561        Slayden  36.2913  -87.4656         0.00333         0.25750
# 18562        Chatham  46.3441  -86.9313         0.01542         0.31417
# 18563     Stillwater  41.1506  -76.3693         0.00292         0.15167
#
#        nh3_2020_11_29  nh3_2020_11_30  nh3_2020_12_01  nh3_2020_12_02  \
# ...

# %%
#create colum list and remove lat and lon values to check for duplicates
colums=new.columns.tolist()
colums.remove("lat")
colums.remove("lon"
              
#check for duplicated values             
duplicate = new.duplicated(subset = colums, keep = False).sum()
checking=new.loc[new.duplicated(subset = colums, keep = False), :]
              
#remove all duplicate values where city and gas values are the same  
df=new.drop_duplicates(subset = colums, keep = False)
   
#remove rows with any missing values
df1=df.dropna()
df1 = new.loc[:,~new.columns.duplicated()]
df1
# Out:
#                 city      lat       lon  nh3_2020_11_27  nh3_2020_11_28  \
# 0            Wrigley  35.8997  -87.3537         0.00375         0.27000
# 1              Cowan  37.5601 -120.9888         0.16083        11.61042
# 2      Strattanville  41.2025  -79.3268         0.00542         0.21250
# 3         SmithRiver  41.9249 -124.1494         0.00833         0.32667
# 4           Laddonia  39.2434  -91.6424         0.01792         0.66458
# ...              ...      ...       ...             ...             ...
# 18559     Litchfield  40.3877 -120.3809         0.05208         1.65792
# 18560          Bruce  44.4378  -96.8906         0.06417         1.57958
# 18561        Slayden  36.2913  -87.4656         0.00333         0.25750
# 18562        Chatham  46.3441  -86.9313         0.01542         0.31417
# 18563     Stillwater  41.1506  -76.3693         0.00292         0.15167
#
#        nh3_2020_11_29  nh3_2020_11_30  nh3_2020_12_01  nh3_2020_12_02  \
# ...

# %%
#load dataframe to csv file
df1.to_csv (r'C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\nh3_data_clean.csv', index = False, header=True)

# %%
#insure df load correcty with correct header and new index
df3=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm2_5_data_clean.csv', encoding='latin-1')
df3
# Out:
#                  city      lat       lon  pm2_5_2020_11_27  pm2_5_2020_11_28  \
# 0               Chula  39.9219  -93.4774           0.23292           5.15042
# 1      LittleSturgeon  44.8422  -87.5743           0.40625           6.15917
# 2               Adair  40.4183  -90.4974           0.23500           5.88417
# 3           Hiseville  37.1008  -85.8149           0.18375           7.91000
# 4            Halliday  47.3522 -102.3388           0.02083           0.69333
# ...               ...      ...       ...               ...               ...
# 18521      HotSprings  38.0013  -79.8239           0.10125           3.83708
# 18522            Burt  43.1989  -94.2211           0.25083           2.02708
# 18523      Plainville  38.8049  -87.1515           0.27667           9.80292
# 18524      Drakesboro  37.2176  -87.0493           0.14875           7.64500
# 18525            Bend  40.2561 -122.2095           0.02750           0.94000
#
# ...

# %%
#load all file to create one master file with all the gasses
one=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\co_data_clean.csv', encoding='latin-1')
two=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no_data_clean.csv', encoding='latin-1')
three=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\no2_data_clean.csv', encoding='latin-1')
four=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\o3_data_clean.csv', encoding='latin-1')
five=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\so2_data_clean.csv', encoding='latin-1')
six=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm2_5_data_clean.csv', encoding='latin-1')
seven=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\pm10_data_clean.csv', encoding='latin-1')
eight=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\nh3_data_clean.csv', encoding='latin-1')

# %%
#combine all file to one maseter file
frames=[one,two,three,four,five,six,seven,eight]
new=pd.concat(frames, axis=1)
new
#remove colums that have similar headers (lat,lon would get repeated)
df1 = new.loc[:,~new.columns.duplicated()]
df1
# Out:
#                  city      lat       lon  co_2020_11_27  co_2020_11_28  \
# 0               Chula  39.9219  -93.4774       12.65625      266.61250
# 1      LittleSturgeon  44.8422  -87.5743       10.57000      246.86417
# 2               Adair  40.4183  -90.4974       11.26542      267.72542
# 3           Hiseville  37.1008  -85.8149       12.09958      266.19500
# 4            Halliday  47.3522 -102.3388        8.69250      204.09833
# ...               ...      ...       ...            ...            ...
# 18521      HotSprings  38.0013  -79.8239        9.73542      229.47750
# 18522            Burt  43.1989  -94.2211       13.62958      237.40542
# 18523      Plainville  38.8049  -87.1515       12.09958      275.65292
# 18524      Drakesboro  37.2176  -87.0493       11.26542      283.44083
# 18525            Bend  40.2561 -122.2095        9.73542      240.32542
#
#        co_2020_11_29  co_2020_11_30  co_2020_12_01  co_2020_12_02  \
# ...

# %%
#create csv for master df
df1.to_csv (r'C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\all_data_clean.csv', index = False, header=True)

# %%
#read master to insure proper load and read
df=pd.read_csv('C:\\Users\\Kurly\\Downloads\\Universal-Embeddings-testing\\Universal-Embeddings-Nick\\data\\all_data_clean.csv', encoding='latin-1')
df
# Out:
#                  city      lat       lon  co_2020_11_27  co_2020_11_28  \
# 0               Chula  39.9219  -93.4774       12.65625      266.61250
# 1      LittleSturgeon  44.8422  -87.5743       10.57000      246.86417
# 2               Adair  40.4183  -90.4974       11.26542      267.72542
# 3           Hiseville  37.1008  -85.8149       12.09958      266.19500
# 4            Halliday  47.3522 -102.3388        8.69250      204.09833
# ...               ...      ...       ...            ...            ...
# 18521      HotSprings  38.0013  -79.8239        9.73542      229.47750
# 18522            Burt  43.1989  -94.2211       13.62958      237.40542
# 18523      Plainville  38.8049  -87.1515       12.09958      275.65292
# 18524      Drakesboro  37.2176  -87.0493       11.26542      283.44083
# 18525            Bend  40.2561 -122.2095        9.73542      240.32542
#
#        co_2020_11_29  co_2020_11_30  co_2020_12_01  co_2020_12_02  \
# ...
